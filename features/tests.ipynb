# %%
import pandas as pd
import numpy as np
import joblib
import os

# %%
tensor_path = os.path.join("..", "data", "tensor.joblib")

# %%
tensor_df = pd.read_csv(tensor_path)

# %%
tensor_df.shape
# Out:
# (884421, 97)

# %%
tensor_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  0      1         2         3         4         5  \
# 0           0             0  0  False  0.000000  0.000000  0.000000  0.000000
# 1           1             1  1  False  6.243333  0.000000  6.251348  0.000000
# 2           2             2  2  False  6.251348  6.243333  6.251348  6.251348
# 3           3             3  3  False  6.243333  6.251348  6.251348  6.251348
# 4           4             4  4  False  6.243333  6.243333  6.243333  6.251348
#
#           6         7  ...        85        86        87        88        89  \
# 0  0.000000  0.000000  ...  6.243333  6.243333  6.247340  6.247340  6.247340
# 1  6.235319  0.000000  ...  6.243333  6.243333  6.191239  6.191239  6.191239
# 2  6.243333  6.235319  ...  6.243333  6.243333  6.147159  6.147159  6.147159
# 3  6.243333  6.243333  ...  6.243333  6.243333  6.135137  6.135137  6.135137
# 4  6.235319  6.243333  ...  6.243333  6.243333  6.135137  6.135137  6.135137
#
# ...
